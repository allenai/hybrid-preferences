# %%
import pandas as pd
import joblib

# %%
mp_model = joblib.load("../../data/multipref_linear_model/model.pkl")
hs_model = joblib.load(
    "../../data/AAA_helpsteer2_feats_results/helpsteer2_linear_model/model.pkl"
)

# %%
pd.DataFrame(hs_model.coef_, index=hs_model.feature_names_in_).sort_values(
    by=0, ascending=False
).head(10)
# Out:
#                                                                0
# bertscore::min_val=0.0|max_val=0.33                 1.048687e+08
# rouge::min_val=0.67|max_val=1.0                     1.085489e-02
# rouge::min_val=0.33|max_val=0.67                    1.081437e-02
# rouge::min_val=0.0|max_val=0.33                     1.073534e-02
# analyzer_closed_set::feature_name=subject_of_ex...  5.038677e-03
# analyzer_scalar::feature_name=complexity_of_int...  4.056851e-03
# analyzer_scalar::feature_name=complexity_of_int...  4.054987e-03
# analyzer_scalar::feature_name=complexity_of_int...  3.950513e-03
# bertscore_length::min_val=0.0|max_val=0.33          3.742596e-03
# bertscore_length::min_val=0.67|max_val=1.0          3.740692e-03

# %%
pd.DataFrame(mp_model.coef_, index=mp_model.feature_names_in_).sort_values(
    by=0, ascending=False
).head(50)
# Out:
#                                                                0
# bertscore::min_val=0.0|max_val=0.33                 2.453123e+08
# len_longer::min_val=0.33|max_val=0.67               1.380829e-02
# len_longer::min_val=0.67|max_val=1.0                1.236130e-02
# len_longer::min_val=0.0|max_val=0.33                1.220477e-02
# analyzer_closed_set::feature_name=languages|con...  2.767400e-03
# analyzer_closed_set::feature_name=subject_of_ex...  1.138874e-03
# analyzer_closed_set::feature_name=subject_of_ex...  1.137253e-03
# analyzer_closed_set::feature_name=subject_of_ex...  7.586715e-04
# analyzer_closed_set::feature_name=subject_of_ex...  7.076216e-04
# analyzer_closed_set::feature_name=subject_of_ex...  6.718272e-04
# analyzer_closed_set::feature_name=subject_of_ex...  5.596551e-04
# analyzer_closed_set::feature_name=subject_of_ex...  5.367762e-04
# token_len_diff::min_val=0.67|max_val=1.0            5.248444e-04
# len_shorter::min_val=0.0|max_val=0.33               5.132613e-04
# analyzer_closed_set::feature_name=subject_of_ex...  3.338967e-04
# analyzer_closed_set::feature_name=subject_of_ex...  2.454716e-04
# analyzer_closed_set::feature_name=subject_of_ex...  2.336245e-04
# analyzer_closed_set::feature_name=subject_of_ex...  2.234565e-04
# analyzer_closed_set::feature_name=subject_of_ex...  2.001480e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.941994e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.767073e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.684068e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.584461e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.578380e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.346577e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.326889e-04
# analyzer_open_set::feature_name=type_of_in_cont...  1.321885e-04
# analyzer_closed_set::feature_name=subject_of_ex...  1.307748e-04
# analyzer_closed_set::feature_name=subject_of_ex...  9.896293e-05
# analyzer_open_set::feature_name=format_constrai...  2.466087e-05
# analyzer_closed_set::feature_name=subject_of_ex...  1.886376e-05
# cosine_sim::min_val=0.67|max_val=1.0                4.114593e-06
# analyzer_closed_set::feature_name=subject_of_ex...  3.345743e-06
# analyzer_closed_set::feature_name=subject_of_ex...  5.408000e-16
# cosine_sim::min_val=0.33|max_val=0.67              -2.533831e-05
# analyzer_closed_set::feature_name=subject_of_ex... -4.422573e-05
# analyzer_closed_set::feature_name=subject_of_ex... -5.488646e-05
# analyzer_scalar::feature_name=complexity_of_int... -6.147644e-05
# analyzer_closed_set::feature_name=subject_of_ex... -7.557865e-05
# token_len_diff::min_val=0.0|max_val=0.33           -7.991180e-05
# analyzer_closed_set::feature_name=subject_of_ex... -1.038876e-04
# cosine_sim::min_val=0.0|max_val=0.33               -1.069438e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.131838e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.215088e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.231116e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.398694e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.432734e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.693462e-04
# analyzer_closed_set::feature_name=subject_of_ex... -1.816137e-04
# analyzer_scalar::feature_name=safety_concern|va... -1.933364e-04

# %%
pd.DataFrame(mp_model.coef_, index=mp_model.feature_names_in_).sort_values(
    by=0, ascending=False
).tail(40)
# Out:
#                                                            0
# analyzer_scalar::feature_name=safety_concern|va... -0.000195
# analyzer_scalar::feature_name=safety_concern|va... -0.000210
# analyzer_scalar::feature_name=expertise_level|v... -0.000219
# analyzer_scalar::feature_name=expertise_level|v... -0.000228
# analyzer_closed_set::feature_name=subject_of_ex... -0.000233
# prompt_len::min_val=0.0|max_val=0.33               -0.000239
# rouge::min_val=0.67|max_val=1.0                    -0.000244
# analyzer_closed_set::feature_name=subject_of_ex... -0.000265
# analyzer_closed_set::feature_name=subject_of_ex... -0.000283
# entity_sim::min_val=0.0|max_val=0.33               -0.000284
# prompt_len::min_val=0.33|max_val=0.67              -0.000290
# entity_sim::min_val=0.67|max_val=1.0               -0.000318
# entity_sim::min_val=0.33|max_val=0.67              -0.000329
# rouge::min_val=0.33|max_val=0.67                   -0.000329
# analyzer_scalar::feature_name=safety_concern|va... -0.000332
# analyzer_closed_set::feature_name=subject_of_ex... -0.000347
# analyzer_closed_set::feature_name=subject_of_ex... -0.000348
# rouge::min_val=0.0|max_val=0.33                    -0.000358
# bertscore::min_val=0.33|max_val=0.67               -0.000381
# prompt_len::min_val=0.67|max_val=1.0               -0.000402
# analyzer_scalar::feature_name=complexity_of_int... -0.000402
# analyzer_scalar::feature_name=complexity_of_int... -0.000467
# analyzer_scalar::feature_name=expertise_level|v... -0.000484
# bertscore::min_val=0.67|max_val=1.0                -0.000549
# analyzer_closed_set::feature_name=subject_of_ex... -0.000664
# len_shorter::min_val=0.33|max_val=0.67             -0.000668
# analyzer_closed_set::feature_name=subject_of_ex... -0.000700
# analyzer_closed_set::feature_name=subject_of_ex... -0.000729
# len_shorter::min_val=0.67|max_val=1.0              -0.000776
# analyzer_closed_set::feature_name=subject_of_ex... -0.000962
# token_len_diff::min_val=0.33|max_val=0.67          -0.001375
# analyzer_closed_set::feature_name=subject_of_ex... -0.002156
# bertscore_length::min_val=0.67|max_val=1.0         -0.003590
# bertscore_length::min_val=0.0|max_val=0.33         -0.003599
# bertscore_length::min_val=0.33|max_val=0.67        -0.003600
# analyzer_closed_set::feature_name=subject_of_ex... -0.003679
# analyzer_scalar::feature_name=open_endedness|va... -0.008974
# analyzer_scalar::feature_name=open_endedness|va... -0.009086
# analyzer_scalar::feature_name=open_endedness|va... -0.009105
# analyzer_scalar::feature_name=open_endedness|va... -0.009244
