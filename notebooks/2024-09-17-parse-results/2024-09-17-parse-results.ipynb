# %%
rewardbench_scores = {
    "Helpsteer2": {
        "human_100": {"score": 0.7244862062, "std": 0.01928079111},
        "human_75": {
            "random": {"score": 0.7308591812, "std": 0.01984530553},
            "top_k_gain_ours": {"score": 0.7707158799, "std": 0.009104445485},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6989520207, "std": 0.01386195063},
            "top_k_gain_ours": {"score": 0.7449719449, "std": 0.001539693934},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.7195659028, "std": 0.0165237678},
            "top_k_gain_ours": {"score": 0.7304071777, "std": 0.004873294347},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6589146105, "std": 0.02987566205},
    },
    "Multipref": {
        "human_100": {"score": 0.6036541233, "std": 0.01432544196},
        "human_75": {
            "random": {"score": 0.6094084237, "std": 0.01248556154},
            "top_k_gain_ours": {"score": 0.6120927052, "std": 0.019055836901},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6294707783, "std": 0.03224571136},
            "top_k_gain_ours": {"score": 0.6838182298, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.6440943955, "std": None},
            "top_k_gain_ours": {"score": 0.6632277603, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6647963033, "std": None},
    },
    "Chatarena": {
        "human_100": {"score": 0.5900274236, "std": None},
        "human_75": {
            "random": {"score": 0.6150350983, "std": None},
            "top_k_gain_ours": {"score": 0.6117267581, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6318025093, "std": None},
            "top_k_gain_ours": {"score": 0.6670979359, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.6590068369, "std": None},
            "top_k_gain_ours": {"score": 0.6633400028, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.7161539026, "std": None},
    },
    "Alpacafarm": {
        "human_100": {"score": 0.5506994896, "std": None},
        "human_75": {
            "random": {"score": 0.5638841148, "std": None},
            "top_k_gain_ours": {"score": 0.5728094646, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.5647307388, "std": None},
            "top_k_gain_ours": {"score": 0.5808630176, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.5808142143, "std": None},
            "top_k_gain_ours": {"score": 0.6137369466, "std": None},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6085676366, "std": None},
    },
}

# %%
rewardbench_scores
# Out:
# {'Helpsteer2': {'human_100': {'score': 0.7244862062, 'std': None},
#   'human_75': {'random': {'score': 0.7308591812, 'std': None},
#    'top_k_gain_ours': {'score': 0.7707158799, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_50': {'random': {'score': 0.6989520207, 'std': None},
#    'top_k_gain_ours': {'score': 0.7449719449, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_25': {'random': {'score': 0.7295659028, 'std': None},
#    'top_k_gain_ours': {'score': 0.7304071777, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_0': {'score': 0.6589146105, 'std': None}},
#  'Multipref': {'human_100': {'score': 0.6036541233, 'std': None},
#   'human_75': {'random': {'score': 0.6094084237, 'std': None},
#    'top_k_gain_ours': {'score': 0.6120927052, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_50': {'random': {'score': 0.6294707783, 'std': None},
#    'top_k_gain_ours': {'score': 0.6838182298, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_25': {'random': {'score': 0.6440943955, 'std': None},
#    'top_k_gain_ours': {'score': 0.6632277603, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_0': {'score': 0.6647963033, 'std': None}},
#  'Chatarena': {'human_100': {'score': 0.5900274236, 'std': None},
#   'human_75': {'random': {'score': 0.6150350983, 'std': None},
#    'top_k_gain_ours': {'score': 0.6117267581, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_50': {'random': {'score': 0.6318025093, 'std': None},
#    'top_k_gain_ours': {'score': 0.6670979359, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_25': {'random': {'score': 0.6590068369, 'std': None},
#    'top_k_gain_ours': {'score': 0.6633400028, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_0': {'score': 0.7161539026, 'std': None}},
#  'Alpacafarm': {'human_100': {'score': 0.5506994896, 'std': None},
#   'human_75': {'random': {'score': 0.5638841148, 'std': None},
#    'top_k_gain_ours': {'score': 0.5728094646, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_50': {'random': {'score': 0.5647307388, 'std': None},
#    'top_k_gain_ours': {'score': 0.5808630176, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_25': {'random': {'score': 0.5808142143, 'std': None},
#    'top_k_gain_ours': {'score': 0.6137369466, 'std': None},
#    'linear_predicted': {'score': None, 'std': None}},
#   'human_0': {'score': 0.6085676366, 'std': None}}}
