# %%
rewardbench_scores = {
    "Helpsteer2": {
        "human_100": {"score": 0.7244862062, "std": 0.01928079111},
        "human_75": {
            "random": {"score": 0.7308591812, "std": 0.01984530553},
            "top_k_gain_ours": {"score": 0.7707158799, "std": 0.009104445485},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6989520207, "std": 0.01386195063},
            "top_k_gain_ours": {"score": 0.7449719449, "std": 0.001539693934},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.7195659028, "std": 0.0165237678},
            "top_k_gain_ours": {"score": 0.7304071777, "std": 0.004873294347},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6589146105, "std": 0.02987566205},
    },
    "Multipref": {
        "human_100": {"score": 0.6036541233, "std": 0.01432544196},
        "human_75": {
            "random": {"score": 0.6094084237, "std": 0.01248556154},
            "top_k_gain_ours": {"score": 0.6120927052, "std": 0.019055836901},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6294707783, "std": 0.03224571136},
            "top_k_gain_ours": {"score": 0.6838182298, "std": 0.01636722144},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.6440943955, "std": 0.02714558638},
            "top_k_gain_ours": {"score": 0.6632277603, "std": 0.007049452311},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6647963033, "std": 0.01003279821},
    },
    "Chatarena": {
        "human_100": {"score": 0.5900274236, "std": 0.007598570491},
        "human_75": {
            "random": {"score": 0.6150350983, "std": 0.0219797227},
            "top_k_gain_ours": {"score": 0.6117267581, "std": 0.009331522576},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.6318025093, "std": 0.006035392953},
            "top_k_gain_ours": {"score": 0.6670979359, "std": 0.03309004775},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.6590068369, "std": 0.03126713036},
            "top_k_gain_ours": {"score": 0.6633400028, "std": 0.00103100798},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.7161539026, "std": 0.002284597933},
    },
    "Alpacafarm": {
        "human_100": {"score": 0.5506994896, "std": 0.01279058507},
        "human_75": {
            "random": {"score": 0.5638841148, "std": 0.005765289053},
            "top_k_gain_ours": {"score": 0.5728094646, "std": 0.000270931992},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_50": {
            "random": {"score": 0.5647307388, "std": 0.01460280667},
            "top_k_gain_ours": {"score": 0.5808630176, "std": 0.003225420498},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_25": {
            "random": {"score": 0.5808142143, "std": 0.0243554648},
            "top_k_gain_ours": {"score": 0.6137369466, "std": 0.01081772558},
            "linear_predicted": {"score": None, "std": None},
        },
        "human_0": {"score": 0.6085676366, "std": 0.01703507856},
    },
}

# %%
import json

with open("../../rewardbench_helpsteer2_linear_features.json", "w") as f:
    json.dump(rewardbench_scores, f)
